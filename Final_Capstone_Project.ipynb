# %% [markdown]
# # **A program For Photographers Event**

# %% [markdown]
# ## **Introduction**

# %% [markdown]
# Mycompany is a corporation based in Toronto performing event management. Currently, it is working on a project to establish an event for 7 days for a group of photographers from all over the world. The company must create a good program, including invitation to a hotel of residence, a hall for meetings, places of landscape to visit, stores for shopping, restaurants and cafes. The company aims at making a list of places of landscape in Toronto, including the nearest restaurants, cafes, and shopping stores for each place.

# %% [markdown]
# ## **Data Description**

# %% [markdown]
# The data used for this project is provided by Foursquare location data. The data are grouped by landscape area, and each area included the information about this area and all information about restaurants, cafes, and stores which in this area.

# %% [markdown]
# ## **Table of contents**

# %% [markdown]
# #### 01- Import Libraries
# #### 02- Define Foursquare Credentials
# #### 03- Define the city and get its latitude & longitude
# #### 04- Search for Hotels & clean dataframe
# #### 05- Search for Parks & clean dataframe
# #### 06- Search for Restaurants & clean dataframe
# #### 07- Search for Cafeteria & clean dataframe
# #### 08- Search for Shopping Stores & clean dataframe
# #### 09- Generate map to visualize hotels, shopping stores and Cafeteria and how they cluster together
# #### 10- Generate map to visualize Park, Restaurant and Cafeteria and how they cluster together

# %% [markdown]
# ## **Import Libraries**

# %%
import requests # to handle requests
import pandas as pd # for data analsysis
import numpy as np # to handle data in a vectorized manner

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
#tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library
# Out:
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.

# %% [markdown]
# ## **Define Foursquare Credentials**

# %%
ClIENT_ID = '4FQQJE2LMGVLERRRE2BOFR1LQQR5ZEHFLTD1WRAFKOFT4TI0' # your Foursquare ID
ClIENT_SECRET = 'RCSNR5TH31NQRG2QYCHK101HRMTUZHBB2TSJ1CJU5UOGRXRQ' # your Foursquare Secret
VERSION = '20180604'
LIMIT =30
print('Your credentails:')
print('Foursquare_ID: ' + ClIENT_ID)
print('Foursquare_Secret:' + ClIENT_SECRET)
# Out:
# Your credentails:
# Foursquare_ID: 4FQQJE2LMGVLERRRE2BOFR1LQQR5ZEHFLTD1WRAFKOFT4TI0
# Foursquare_Secret:RCSNR5TH31NQRG2QYCHK101HRMTUZHBB2TSJ1CJU5UOGRXRQ

# %% [markdown]
# ## **Define the city and get its latitude & longitude**

# %%
# define the city and get its latitude & longitude 
city = 'Toronto'
geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(city)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 43.653963 -79.387207

# %% [markdown]
# ## **Search for Hotels**

# %%
# search for hotels
search_query = 'Hotel'
radius = 500

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'\
.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=4FQQJE2LMGVLERRRE2BOFR1LQQR5ZEHFLTD1WRAFKOFT4TI0&client_secret=RCSNR5TH31NQRG2QYCHK101HRMTUZHBB2TSJ1CJU5UOGRXRQ&ll=43.653963,-79.387207&v=20180604&query=Hotel&radius=500&limit=30'

# %%
# Send the GET Request and examine the results
results = requests.get(url).json()
#results

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...    False
# 1  [{'id': '4bf58dd8d48988d1e7931735', 'name': 'J...    False
# 2  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...    False
# 3  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...    False
# 4  [{'id': '56aa371be4b08b9a8d5734cf', 'name': 'B...    False
#
#                          id       location.address location.cc location.city  \
# 0  4ab2d511f964a5209b6c20e3  123 Queen Street West          CA       Toronto
# 1  4b68aed1f964a520de862be3         194 Queen St W          CA       Toronto
# 2  52ce14b0498e50457ce11780    108 Chestnut Street          CA       Toronto
# 3  4f343a31e4b0230a3b337a90         123 Test Drive          CA       Toronto
# 4  5545d07e498e2facac03f666  123 Queen Street West          CA       Toronto
#
#   location.country location.crossStreet  location.distance  \
# 0           Canada          at York St.                390
# 1           Canada  Queen & St. Patrick                400
# 2           Canada          Dundas St W                124
# 3           Canada      at somewhere St                500
# 4           Canada        at Bay Street                376
#
#                            location.formattedAddress  \
# 0  [123 Queen Street West (at York St.), Toronto ...
# 1  [194 Queen St W (Queen & St. Patrick), Toronto...
# 2  [108 Chestnut Street (Dundas St W), Toronto ON...
# 3  [123 Test Drive (at somewhere St), Toronto ON ...
# 4  [123 Queen Street West (at Bay Street), Toront...
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 43.6511441, 'lng'...     43.651144
# 1  [{'label': 'display', 'lat': 43.65050475544005...     43.650505
# 2  [{'label': 'display', 'lat': 43.6546083, 'lng'...     43.654608
# 3  [{'label': 'display', 'lat': 43.658434, 'lng':...     43.658434
# 4  [{'label': 'display', 'lat': 43.65119976208405...     43.651200
#
#    location.lng location.neighborhood location.postalCode location.state  \
# 0    -79.384329                   NaN             M5H 2M9             ON
# 1    -79.388577                   NaN             M5V 1Z1             ON
# 2    -79.385942                   NaN             M5G 1R3             ON
# 3    -79.387894                   NaN             M2M 2M2             ON
# 4    -79.384520    Financial District                 NaN             ON
#
#                                              name    referralId venuePage.id
# 0                   Sheraton Centre Toronto Hotel  v-1568567551          NaN
# 1                  The Rex Hotel Jazz & Blues Bar  v-1568567551     62225795
# 2     DoubleTree by Hilton Hotel Toronto Downtown  v-1568567551          NaN
# 3                                  VFM Test Hotel  v-1568567551          NaN
# 4  Sheraton Centre Toronto Hotel - Grand Ballroom  v-1568567551          NaN

# %% [markdown]
# ## **Clean Hotel Dataframe**

# %%
# keep only columns that include venue name, and anything that is associated with location
clean_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')]+ ['id']
clean_dataframe = dataframe.loc[:,clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
clean_dataframe['categories'] = clean_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_dataframe.columns = [column.split('.')[-1] for column in clean_dataframe.columns]

clean_dataframe.head()
# Out:
#                                              name categories  \
# 0                   Sheraton Centre Toronto Hotel      Hotel
# 1                  The Rex Hotel Jazz & Blues Bar  Jazz Club
# 2     DoubleTree by Hilton Hotel Toronto Downtown      Hotel
# 3                                  VFM Test Hotel      Hotel
# 4  Sheraton Centre Toronto Hotel - Grand Ballroom   Ballroom
#
#                  address  cc     city country          crossStreet  distance  \
# 0  123 Queen Street West  CA  Toronto  Canada          at York St.       390
# 1         194 Queen St W  CA  Toronto  Canada  Queen & St. Patrick       400
# 2    108 Chestnut Street  CA  Toronto  Canada          Dundas St W       124
# 3         123 Test Drive  CA  Toronto  Canada      at somewhere St       500
# 4  123 Queen Street West  CA  Toronto  Canada        at Bay Street       376
#
#                                     formattedAddress  \
# 0  [123 Queen Street West (at York St.), Toronto ...
# 1  [194 Queen St W (Queen & St. Patrick), Toronto...
# 2  [108 Chestnut Street (Dundas St W), Toronto ON...
# 3  [123 Test Drive (at somewhere St), Toronto ON ...
# 4  [123 Queen Street West (at Bay Street), Toront...
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 43.6511441, 'lng'...  43.651144 -79.384329
# 1  [{'label': 'display', 'lat': 43.65050475544005...  43.650505 -79.388577
# 2  [{'label': 'display', 'lat': 43.6546083, 'lng'...  43.654608 -79.385942
# 3  [{'label': 'display', 'lat': 43.658434, 'lng':...  43.658434 -79.387894
# 4  [{'label': 'display', 'lat': 43.65119976208405...  43.651200 -79.384520
#
#          neighborhood postalCode state                        id
# 0                 NaN    M5H 2M9    ON  4ab2d511f964a5209b6c20e3
# 1                 NaN    M5V 1Z1    ON  4b68aed1f964a520de862be3
# 2                 NaN    M5G 1R3    ON  52ce14b0498e50457ce11780
# 3                 NaN    M2M 2M2    ON  4f343a31e4b0230a3b337a90
# 4  Financial District        NaN    ON  5545d07e498e2facac03f666

# %%
# delete unnecessary columns
clean_dataframe2= clean_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs','neighborhood', 'id'], axis=1)
clean_dataframe2
# Out:
#                                               name              categories  \
# 0                    Sheraton Centre Toronto Hotel                   Hotel
# 1                   The Rex Hotel Jazz & Blues Bar               Jazz Club
# 2      DoubleTree by Hilton Hotel Toronto Downtown                   Hotel
# 3                                   VFM Test Hotel                   Hotel
# 4   Sheraton Centre Toronto Hotel - Grand Ballroom                Ballroom
# 5                                  Stathcona Hotel                   Hotel
# 6                Sheraton Centre Hotel Club Lounge                  Lounge
# 7    hilton hotel, richmondstreet E, 145,  toronto              Hotel Pool
# 8                                        650 Hotel                   Hotel
# 9                                Be SixFifty Hotel                   Hotel
# 10                              Shangri-La Toronto                   Hotel
# 11    Marriott Downtown at CF Toronto Eaton Centre                   Hotel
# 12                                  Hilton Toronto                   Hotel
# 13                           89 Chestnut Residence  College Residence Hall
# 14                   Op mijn hotelkamer In Toronto                   Hotel
# 15                                  Fitness Centre                     Gym
# 16          Lobby Lounge at the Shangri-La Toronto                  Lounge
# 17                                            Pool                    Pool
# 18                                   Bistro on Two          Breakfast Spot
# 19                                   Kumar For Men             Men's Store
# 20                                  Fitness Centre                     Gym
# 21                                  Grand Ballroom             Event Space
#
#                   address        lat        lng postalCode    state
# 0   123 Queen Street West  43.651144 -79.384329    M5H 2M9       ON
# 1          194 Queen St W  43.650505 -79.388577    M5V 1Z1       ON
# 2     108 Chestnut Street  43.654608 -79.385942    M5G 1R3       ON
# 3          123 Test Drive  43.658434 -79.387894    M2M 2M2       ON
# 4   123 Queen Street West  43.651200 -79.384520        NaN       ON
# 5                     NaN  43.654947 -79.386359        NaN       ON
# 6                     NaN  43.651063 -79.384527    M5H 2M9       ON
# 7   Richmondstreet E, 145  43.650625 -79.385488        NaN       ON
# 8          650 Bay Street  43.657046 -79.384411        NaN       ON
# 9          650 Bay Street  43.657120 -79.384560        NaN       ON
# 10    188 University Ave.  43.649129 -79.386557    M5H 0A3       ON
# 11         525 Bay Street  43.654728 -79.382422    M5G 2L2       ON
# 12      145 Richmond St W  43.649946 -79.385479    M5H 2L2       ON
# 13        89 Chestnut St.  43.654160 -79.385291    M5G 1R1       ON
# 14                    NaN  43.654235 -79.386208        NaN       ON
# 15            525 Bay St.  43.654690 -79.381739    M5G 2L2       ON
# 16    188 University Ave.  43.649155 -79.386546    M5H 0A3       ON
# 17       Intercontinental  43.650975 -79.384053        NaN  Ontario
# 18        123 Queen St. W  43.651011 -79.383658    M5H 2M9       ON
# 19        Sheraton Centre  43.651044 -79.383302    M5H 2M9       ON
# 20        Sheraton Centre  43.650985 -79.384002    M5H 2M9       ON
# 21        123 Queen St. W  43.651217 -79.383771    M5H 2M9       ON

# %%
# delete rows with none values
clean_dataframe3 = clean_dataframe2.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
clean_dataframe3
# Out:
#                                             name              categories  \
# 0                  Sheraton Centre Toronto Hotel                   Hotel
# 1                 The Rex Hotel Jazz & Blues Bar               Jazz Club
# 2    DoubleTree by Hilton Hotel Toronto Downtown                   Hotel
# 3                                 VFM Test Hotel                   Hotel
# 10                            Shangri-La Toronto                   Hotel
# 11  Marriott Downtown at CF Toronto Eaton Centre                   Hotel
# 12                                Hilton Toronto                   Hotel
# 13                         89 Chestnut Residence  College Residence Hall
# 15                                Fitness Centre                     Gym
# 16        Lobby Lounge at the Shangri-La Toronto                  Lounge
# 18                                 Bistro on Two          Breakfast Spot
# 19                                 Kumar For Men             Men's Store
# 20                                Fitness Centre                     Gym
# 21                                Grand Ballroom             Event Space
#
#                   address        lat        lng postalCode state
# 0   123 Queen Street West  43.651144 -79.384329    M5H 2M9    ON
# 1          194 Queen St W  43.650505 -79.388577    M5V 1Z1    ON
# 2     108 Chestnut Street  43.654608 -79.385942    M5G 1R3    ON
# 3          123 Test Drive  43.658434 -79.387894    M2M 2M2    ON
# 10    188 University Ave.  43.649129 -79.386557    M5H 0A3    ON
# 11         525 Bay Street  43.654728 -79.382422    M5G 2L2    ON
# 12      145 Richmond St W  43.649946 -79.385479    M5H 2L2    ON
# 13        89 Chestnut St.  43.654160 -79.385291    M5G 1R1    ON
# 15            525 Bay St.  43.654690 -79.381739    M5G 2L2    ON
# 16    188 University Ave.  43.649155 -79.386546    M5H 0A3    ON
# 18        123 Queen St. W  43.651011 -79.383658    M5H 2M9    ON
# 19        Sheraton Centre  43.651044 -79.383302    M5H 2M9    ON
# 20        Sheraton Centre  43.650985 -79.384002    M5H 2M9    ON
# 21        123 Queen St. W  43.651217 -79.383771    M5H 2M9    ON

# %%
# delete rows which its category is not Hotel or Event Space
array= ['Hotel', 'Event Space']
hotel_dataframe= clean_dataframe3.loc[clean_dataframe3['categories'].isin(array)]
hotel_dataframe
# Out:
#                                             name   categories  \
# 0                  Sheraton Centre Toronto Hotel        Hotel
# 2    DoubleTree by Hilton Hotel Toronto Downtown        Hotel
# 3                                 VFM Test Hotel        Hotel
# 10                            Shangri-La Toronto        Hotel
# 11  Marriott Downtown at CF Toronto Eaton Centre        Hotel
# 12                                Hilton Toronto        Hotel
# 21                                Grand Ballroom  Event Space
#
#                   address        lat        lng postalCode state
# 0   123 Queen Street West  43.651144 -79.384329    M5H 2M9    ON
# 2     108 Chestnut Street  43.654608 -79.385942    M5G 1R3    ON
# 3          123 Test Drive  43.658434 -79.387894    M2M 2M2    ON
# 10    188 University Ave.  43.649129 -79.386557    M5H 0A3    ON
# 11         525 Bay Street  43.654728 -79.382422    M5G 2L2    ON
# 12      145 Richmond St W  43.649946 -79.385479    M5H 2L2    ON
# 21        123 Queen St. W  43.651217 -79.383771    M5H 2M9    ON

# %%
# delete rows which has duplicate hotel's name
df_hotels = hotel_dataframe.drop_duplicates(subset='name', keep="first")
df_hotels
# Out:
#                                             name   categories  \
# 0                  Sheraton Centre Toronto Hotel        Hotel
# 2    DoubleTree by Hilton Hotel Toronto Downtown        Hotel
# 3                                 VFM Test Hotel        Hotel
# 10                            Shangri-La Toronto        Hotel
# 11  Marriott Downtown at CF Toronto Eaton Centre        Hotel
# 12                                Hilton Toronto        Hotel
# 21                                Grand Ballroom  Event Space
#
#                   address        lat        lng postalCode state
# 0   123 Queen Street West  43.651144 -79.384329    M5H 2M9    ON
# 2     108 Chestnut Street  43.654608 -79.385942    M5G 1R3    ON
# 3          123 Test Drive  43.658434 -79.387894    M2M 2M2    ON
# 10    188 University Ave.  43.649129 -79.386557    M5H 0A3    ON
# 11         525 Bay Street  43.654728 -79.382422    M5G 2L2    ON
# 12      145 Richmond St W  43.649946 -79.385479    M5H 2L2    ON
# 21        123 Queen St. W  43.651217 -79.383771    M5H 2M9    ON

# %%
# choose the hotel which has the same postalCode with the event space
df_hotel = df_hotels[df_hotels.postalCode == 'M5H 2M9']
df_hotel
# Out:
#                              name   categories                address  \
# 0   Sheraton Centre Toronto Hotel        Hotel  123 Queen Street West
# 21                 Grand Ballroom  Event Space        123 Queen St. W
#
#           lat        lng postalCode state
# 0   43.651144 -79.384329    M5H 2M9    ON
# 21  43.651217 -79.383771    M5H 2M9    ON

# %% [markdown]
# ## **Search for Parks**

# %%
# search for Parks
search_query = 'Park'
radius = 10000

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'\
.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=4FQQJE2LMGVLERRRE2BOFR1LQQR5ZEHFLTD1WRAFKOFT4TI0&client_secret=RCSNR5TH31NQRG2QYCHK101HRMTUZHBB2TSJ1CJU5UOGRXRQ&ll=43.653963,-79.387207&v=20180604&query=Park&radius=10000&limit=30'

# %%
# Send the GET Request and examine the results
presults = requests.get(url).json()
#presults

# %%
# assign relevant part of JSON to venues
venues = presults['response']['venues']

# tranform venues into a dataframe
park_dataframe = json_normalize(venues)
park_dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...    False
# 1  [{'id': '4bf58dd8d48988d1fd931735', 'name': 'M...    False
# 2  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...    False
# 3  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...    False
# 4  [{'id': '4bf58dd8d48988d175941735', 'name': 'G...    False
#
#                          id    location.address location.cc location.city  \
# 0  4b54deadf964a520a3d027e3                 NaN          CA       Toronto
# 1  4b170e47f964a5208cc123e3  691 University Ave          CA       Toronto
# 2  4ad4c05ef964a520bdf620e3  1053 Dundas St. W.          CA       Toronto
# 3  4bb3c91a2397b7134d9f38b3         Spadina Ave          CA       Toronto
# 4  59ddd7469ba3e51a75459568    382 Yonge Street          CA       Toronto
#
#   location.country location.crossStreet  location.distance  \
# 0           Canada                  NaN                423
# 1           Canada        at College St                716
# 2           Canada    at Gore Vale Ave.               2271
# 3           Canada   at Wellington St W               1223
# 4           Canada                  NaN                695
#
#                            location.formattedAddress  \
# 0  [btwn College, University, Queen & Spadina, To...
# 1  [691 University Ave (at College St), Toronto O...
# 2  [1053 Dundas St. W. (at Gore Vale Ave.), Toron...
# 3  [Spadina Ave (at Wellington St W), Toronto ON,...
# 4     [382 Yonge Street, Toronto ON M5G 1S8, Canada]
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 43.65248755299856...     43.652488
# 1  [{'label': 'display', 'lat': 43.66000635700919...     43.660006
# 2  [{'label': 'display', 'lat': 43.64707192840234...     43.647072
# 3  [{'label': 'display', 'lat': 43.64422227794523...     43.644222
# 4  [{'label': 'display', 'lat': 43.6592634, 'lng'...     43.659263
#
#    location.lng location.neighborhood location.postalCode location.state  \
# 0    -79.392053                   NaN                 NaN             ON
# 1    -79.390272                   NaN             M5G 2P1             ON
# 2    -79.413756                   NaN             M5H 2N2             ON
# 3    -79.394230                   NaN                 NaN             ON
# 4    -79.382632                   NaN             M5G 1S8             ON
#
#                             name    referralId venuePage.id
# 0                    Grange Park  v-1568567560          NaN
# 1    Queen's Park Subway Station  v-1568567560          NaN
# 2         Trinity Bellwoods Park  v-1568567560          NaN
# 3           Clarence Square Park  v-1568567560          NaN
# 4  Crunch Fitness - College Park  v-1568567560    532736199

# %% [markdown]
# ## **Clean Park Dataframe**

# %%
# keep only columns that include venue name, and anything that is associated with location
park_clean_columns = ['name', 'categories'] + [col for col in park_dataframe.columns if col.startswith('location.')]+ ['id']
clean_park_dataframe = park_dataframe.loc[:,park_clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list1 = row['categories']
    except:
        categories_list1 = row['venue.categories']
        
    if len(categories_list1) == 0:
        return None
    else:
        return categories_list1[0]['name']

# filter the category for each row
clean_park_dataframe['categories'] = clean_park_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_park_dataframe.columns = [column.split('.')[-1] for column in clean_park_dataframe.columns]

clean_park_dataframe.head()
# Out:
#                             name            categories             address  \
# 0                    Grange Park                  Park                 NaN
# 1    Queen's Park Subway Station         Metro Station  691 University Ave
# 2         Trinity Bellwoods Park                  Park  1053 Dundas St. W.
# 3           Clarence Square Park                  Park         Spadina Ave
# 4  Crunch Fitness - College Park  Gym / Fitness Center    382 Yonge Street
#
#    cc     city country         crossStreet  distance  \
# 0  CA  Toronto  Canada                 NaN       423
# 1  CA  Toronto  Canada       at College St       716
# 2  CA  Toronto  Canada   at Gore Vale Ave.      2271
# 3  CA  Toronto  Canada  at Wellington St W      1223
# 4  CA  Toronto  Canada                 NaN       695
#
#                                     formattedAddress  \
# 0  [btwn College, University, Queen & Spadina, To...
# 1  [691 University Ave (at College St), Toronto O...
# 2  [1053 Dundas St. W. (at Gore Vale Ave.), Toron...
# 3  [Spadina Ave (at Wellington St W), Toronto ON,...
# 4     [382 Yonge Street, Toronto ON M5G 1S8, Canada]
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 43.65248755299856...  43.652488 -79.392053
# 1  [{'label': 'display', 'lat': 43.66000635700919...  43.660006 -79.390272
# 2  [{'label': 'display', 'lat': 43.64707192840234...  43.647072 -79.413756
# 3  [{'label': 'display', 'lat': 43.64422227794523...  43.644222 -79.394230
# 4  [{'label': 'display', 'lat': 43.6592634, 'lng'...  43.659263 -79.382632
#
#   neighborhood postalCode state                        id
# 0          NaN        NaN    ON  4b54deadf964a520a3d027e3
# 1          NaN    M5G 2P1    ON  4b170e47f964a5208cc123e3
# 2          NaN    M5H 2N2    ON  4ad4c05ef964a520bdf620e3
# 3          NaN        NaN    ON  4bb3c91a2397b7134d9f38b3
# 4          NaN    M5G 1S8    ON  59ddd7469ba3e51a75459568

# %%
# delete unnecessary columns
clean_park_dataframe2= clean_park_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs', 'id'], axis=1)
clean_park_dataframe2
# Out:
#                                        name  \
# 0                               Grange Park
# 1               Queen's Park Subway Station
# 2                    Trinity Bellwoods Park
# 3                      Clarence Square Park
# 4             Crunch Fitness - College Park
# 5                      Bellevue Square Park
# 6                               Berczy Park
# 7                              Queen's Park
# 8         St. Andrews Playground / Dog Park
# 9                                  HTO Park
# 10                            One Park Lane
# 11         Residences at College Park North
# 12                      Riverdale Park East
# 13       TTC Streetcar #403 - Victoria park
# 14                      Riverdale Park West
# 15                          Coronation Park
# 16                       Canoe Landing Park
# 17  GoodLife Fitness Toronto Bloor and Park
# 18                                High Park
# 19                             Stanley Park
# 20                             College Park
# 21                   Physiomed College Park
# 22                          Roundhouse Park
# 23                              Regent Park
# 24                      RBC WaterPark Place
# 25                  Cawthra Square Dog Park
# 26         Toothworks - College Park Dental
# 27                  Moss Park Tennis Courts
# 28                  Stanley Park (Dog Park)
# 29                        Barbara Hall Park
#
#                                   categories                       address  \
# 0                                       Park                           NaN
# 1                              Metro Station            691 University Ave
# 2                                       Park            1053 Dundas St. W.
# 3                                       Park                   Spadina Ave
# 4                       Gym / Fitness Center              382 Yonge Street
# 5                                       Park  btwn Bellevue & Augusta Ave.
# 6                                       Park        35 Wellington St. East
# 7                                       Park               University Ave.
# 8                                       Park      450 Adelaide Street West
# 9                                       Park                  Queen's Quay
# 10  Residential Building (Apartment / Condo)                 280 Simcoe St
# 11  Residential Building (Apartment / Condo)                   763 Bay St.
# 12                                      Park             550 Broadview Ave
# 13                        Light Rail Station                           NaN
# 14                                      Park               500 Gerrard St.
# 15                                      Park        711 Lake Shore Blvd. W
# 16                                      Park             50 Fort York Blvd
# 17                                       Gym                     8 Park Rd
# 18                                      Park              1873 Bloor St. W
# 19                                      Park              King Street West
# 20                             Shopping Mall                  444 Yonge St
# 21                            Medical Center                  382 Yonge St
# 22                                      Park             255 Bremner Blvd.
# 23                                      Park              620 Dundas St E.
# 24                                    Office                88 Queens Quay
# 25                                   Dog Run                519 Church St.
# 26                          Dentist's Office        444 Yonge St, Unit M16
# 27                              Tennis Court                     Moss Park
# 28                                   Dog Run              King Street West
# 29                                      Park             519 Church Street
#
#           lat        lng            neighborhood postalCode state
# 0   43.652488 -79.392053                     NaN        NaN    ON
# 1   43.660006 -79.390272                     NaN    M5G 2P1    ON
# 2   43.647072 -79.413756                     NaN    M5H 2N2    ON
# 3   43.644222 -79.394230                     NaN        NaN    ON
# 4   43.659263 -79.382632                     NaN    M5G 1S8    ON
# 5   43.653610 -79.402199                     NaN    M5T 2N4    ON
# 6   43.648048 -79.375172                     NaN        NaN    ON
# 7   43.663946 -79.392180                     NaN    M5R 2E8    ON
# 8   43.647388 -79.398752                     NaN        NaN    ON
# 9   43.637949 -79.387820                     NaN        NaN    ON
# 10  43.655442 -79.390056                     NaN    M5T 2Y5    ON
# 11  43.659822 -79.385159                     NaN    M5G 2R3    ON
# 12  43.669951 -79.355493                     NaN    M4K 2P1    ON
# 13  43.650735 -79.386921                     NaN        NaN    ON
# 14  43.666048 -79.360941                     NaN    M5A 2H3    ON
# 15  43.634553 -79.405403                     NaN    M5V 3T7    ON
# 16  43.638762 -79.397067                     NaN    M5V 3Z1    ON
# 17  43.671302 -79.384691                     NaN    M4W 3G8    ON
# 18  43.646479 -79.463425                     NaN    M6R 2Z3    ON
# 19  43.642395 -79.409330                     NaN        NaN    ON
# 20  43.661237 -79.383603                     NaN    M5B 2H4    ON
# 21  43.659240 -79.382860                     NaN    M5B 1S8    ON
# 22  43.641745 -79.384279  Entertainment District    M5V 3M9    ON
# 23  43.660383 -79.361810                     NaN        NaN    ON
# 24  43.641075 -79.379154                     NaN        NaN    ON
# 25  43.666583 -79.380040                     NaN        NaN    ON
# 26  43.660009 -79.383905                     NaN        NaN    ON
# 27  43.655337 -79.371923                     NaN        NaN    ON
# 28  43.641668 -79.409269                     NaN        NaN    ON
# 29  43.666728 -79.381084                     NaN        NaN    ON

# %%
# delete rows with none values
clean_park_dataframe3 = clean_park_dataframe2.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
clean_park_dataframe3
# Out:
#                name categories            address        lat        lng  \
# 22  Roundhouse Park       Park  255 Bremner Blvd.  43.641745 -79.384279
#
#               neighborhood postalCode state
# 22  Entertainment District    M5V 3M9    ON

# %%
# delete rows which its category is not Park
df_park = clean_park_dataframe3[clean_park_dataframe3.categories == 'Park']
df_park
# Out:
#                name categories            address        lat        lng  \
# 22  Roundhouse Park       Park  255 Bremner Blvd.  43.641745 -79.384279
#
#               neighborhood postalCode state
# 22  Entertainment District    M5V 3M9    ON

# %% [markdown]
# ## **Search for Restaurants**

# %%
# search for Restaurants
search_query = 'Restaurant'
radius = 10000

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=4FQQJE2LMGVLERRRE2BOFR1LQQR5ZEHFLTD1WRAFKOFT4TI0&client_secret=RCSNR5TH31NQRG2QYCHK101HRMTUZHBB2TSJ1CJU5UOGRXRQ&ll=43.653963,-79.387207&v=20180604&query=Restaurant&radius=10000&limit=30'

# %%
# Send the GET Request and examine the results
Rresults = requests.get(url).json()
#Rresults

# %%
# assign relevant part of JSON to venues
venues = Rresults['response']['venues']

# tranform venues into a dataframe
Restaurant_dataframe = json_normalize(venues)
Restaurant_dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1f5931735', 'name': 'D...    False
# 1  [{'id': '4bf58dd8d48988d14e941735', 'name': 'A...    False
# 2  [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...    False
# 3  [{'id': '4bf58dd8d48988d1d1941735', 'name': 'N...    False
# 4  [{'id': '4bf58dd8d48988d1f5931735', 'name': 'D...    False
#
#                          id     location.address location.cc location.city  \
# 0  4ad4c060f964a5207ff720e3     323 Spadina Ave.          CA       Toronto
# 1  4ad4c05ff964a52048f720e3  110 Chestnut Street          CA       Toronto
# 2  4b223f5af964a520ba4424e3        225 Frnt St W          CA       Toronto
# 3  4b266f05f964a520657b24e3      266 Spadina Ave          CA       Toronto
# 4  4b072e9df964a52009f922e3     280 Spadina Ave.          CA       Toronto
#
#   location.country location.crossStreet  location.distance  \
# 0           Canada        at D'Arcy St.                922
# 1           Canada                  NaN                145
# 2           Canada                  NaN               1039
# 3           Canada       at Willison Sq                892
# 4           Canada     at Dundas St. W.                892
#
#                            location.formattedAddress  \
# 0  [323 Spadina Ave. (at D'Arcy St.), Toronto ON ...
# 1  [110 Chestnut Street, Toronto ON M5G 1R3, Canada]
# 2        [225 Frnt St W, Toronto ON M5V 2X3, Canada]
# 3  [266 Spadina Ave (at Willison Sq), Toronto ON ...
# 4  [280 Spadina Ave. (at Dundas St. W.), Toronto ...
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 43.65431754076345...     43.654318
# 1  [{'label': 'display', 'lat': 43.65488413420439...     43.654884
# 2  [{'label': 'display', 'lat': 43.64474919591934...     43.644749
# 3  [{'label': 'display', 'lat': 43.6522783893466,...     43.652278
# 4  [{'label': 'display', 'lat': 43.65278331265585...     43.652783
#
#    location.lng   location.neighborhood location.postalCode location.state  \
# 0    -79.398650       Kensington Market             M5T 2E9             ON
# 1    -79.385931                     NaN             M5G 1R3             ON
# 2    -79.385113  Entertainment District             M5V 2X3             ON
# 3    -79.398039                     NaN             M5T 2E4             ON
# 4    -79.398174                     NaN                 NaN             ON
#
#                                  name    referralId venuePage.id
# 0              Rol San Restaurant 龍笙棧  v-1568567565          NaN
# 1     Hemispheres Restaurant & Bistro  v-1568567565          NaN
# 2              Azure Restaurant & Bar  v-1568567565    136175835
# 3      Goldstone Noodle Restaurant 金石  v-1568567565          NaN
# 4  Sky Dragon Chinese Restaurant 龍翔酒樓  v-1568567565          NaN

# %% [markdown]
# ## **Clean Restaurant Dataframe**

# %%
# keep only columns that include venue name, and anything that is associated with location
Restaurant_clean_columns = ['name', 'categories'] + [col for col in Restaurant_dataframe.columns if col.startswith('location.')]+ ['id']
clean_Restaurant_dataframe = Restaurant_dataframe.loc[:,Restaurant_clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list3 = row['categories']
    except:
        categories_list3 = row['venue.categories']
        
    if len(categories_list3) == 0:
        return None
    else:
        return categories_list3[0]['name']

# filter the category for each row
clean_Restaurant_dataframe['categories'] = clean_Restaurant_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_Restaurant_dataframe.columns = [column.split('.')[-1] for column in clean_Restaurant_dataframe.columns]

clean_Restaurant_dataframe.head()
# Out:
#                                  name           categories  \
# 0              Rol San Restaurant 龍笙棧   Dim Sum Restaurant
# 1     Hemispheres Restaurant & Bistro  American Restaurant
# 2              Azure Restaurant & Bar           Restaurant
# 3      Goldstone Noodle Restaurant 金石         Noodle House
# 4  Sky Dragon Chinese Restaurant 龍翔酒樓   Dim Sum Restaurant
#
#                address  cc     city country       crossStreet  distance  \
# 0     323 Spadina Ave.  CA  Toronto  Canada     at D'Arcy St.       922
# 1  110 Chestnut Street  CA  Toronto  Canada               NaN       145
# 2        225 Frnt St W  CA  Toronto  Canada               NaN      1039
# 3      266 Spadina Ave  CA  Toronto  Canada    at Willison Sq       892
# 4     280 Spadina Ave.  CA  Toronto  Canada  at Dundas St. W.       892
#
#                                     formattedAddress  \
# 0  [323 Spadina Ave. (at D'Arcy St.), Toronto ON ...
# 1  [110 Chestnut Street, Toronto ON M5G 1R3, Canada]
# 2        [225 Frnt St W, Toronto ON M5V 2X3, Canada]
# 3  [266 Spadina Ave (at Willison Sq), Toronto ON ...
# 4  [280 Spadina Ave. (at Dundas St. W.), Toronto ...
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 43.65431754076345...  43.654318 -79.398650
# 1  [{'label': 'display', 'lat': 43.65488413420439...  43.654884 -79.385931
# 2  [{'label': 'display', 'lat': 43.64474919591934...  43.644749 -79.385113
# 3  [{'label': 'display', 'lat': 43.6522783893466,...  43.652278 -79.398039
# 4  [{'label': 'display', 'lat': 43.65278331265585...  43.652783 -79.398174
#
#              neighborhood postalCode state                        id
# 0       Kensington Market    M5T 2E9    ON  4ad4c060f964a5207ff720e3
# 1                     NaN    M5G 1R3    ON  4ad4c05ff964a52048f720e3
# 2  Entertainment District    M5V 2X3    ON  4b223f5af964a520ba4424e3
# 3                     NaN    M5T 2E4    ON  4b266f05f964a520657b24e3
# 4                     NaN        NaN    ON  4b072e9df964a52009f922e3

# %%
# delete unnecessary columns
clean_Restaurant_dataframe2= clean_Restaurant_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs', 'neighborhood', 'id'], axis=1)
clean_Restaurant_dataframe2
# Out:
#                                               name               categories  \
# 0                           Rol San Restaurant 龍笙棧       Dim Sum Restaurant
# 1                  Hemispheres Restaurant & Bistro      American Restaurant
# 2                           Azure Restaurant & Bar               Restaurant
# 3                   Goldstone Noodle Restaurant 金石             Noodle House
# 4               Sky Dragon Chinese Restaurant 龍翔酒樓       Dim Sum Restaurant
# 5                          Swatow Restaurant 汕頭小食家       Chinese Restaurant
# 6                                   360 Restaurant                 Wine Bar
# 7                   The Hot House Restaurant & Bar      American Restaurant
# 8                            Victoria's Restaurant               Restaurant
# 9               North-East Chinese Restaurant 華北美食       Chinese Restaurant
# 10                    Aroma Fine Indian Restaurant        Indian Restaurant
# 11                         Victor Restaurant & Bar                      Bar
# 12  Sassafraz | Cafe | Restaurant | Private Events              Event Space
# 13                        New Sky Restaurant 小沙田食家       Chinese Restaurant
# 14                        Ka Chi Korean Restaurant        Korean Restaurant
# 15             Richtree Natural Market Restaurants               Restaurant
# 16                           ONE Restaurant/Lounge  New American Restaurant
# 17                  Insomnia Restaurant and Lounge               Restaurant
# 18              Some Time BBQ Grill Restaurant 碳烤屋      Szechuan Restaurant
# 19                   Hong Shing Chinese Restaurant       Chinese Restaurant
# 20         Tasty's Caribbean Restaurant & Catering     Caribbean Restaurant
# 21                   Green Tea Restaurant Downtown       Chinese Restaurant
# 22                         The Lakeview Restaurant                    Diner
# 23               Kensington Cornerstone Restaurant           Breakfast Spot
# 24                     Woodlot Restaurant & Bakery  New American Restaurant
# 25                               Studio Restaurant           Breakfast Spot
# 26                           Sightlines Restaurant      American Restaurant
# 27                               SCHOOL Restaurant           Breakfast Spot
# 28                 Kyoto House Japanese Restaurant         Sushi Restaurant
# 29                          The Senator Restaurant                    Diner
#
#                             address        lat        lng postalCode state
# 0                  323 Spadina Ave.  43.654318 -79.398650    M5T 2E9    ON
# 1               110 Chestnut Street  43.654884 -79.385931    M5G 1R3    ON
# 2                     225 Frnt St W  43.644749 -79.385113    M5V 2X3    ON
# 3                   266 Spadina Ave  43.652278 -79.398039    M5T 2E4    ON
# 4                  280 Spadina Ave.  43.652783 -79.398174        NaN    ON
# 5                  309 Spadina Ave.  43.653866 -79.398334    M5T 2E6    ON
# 6                    301 Front St W  43.642537 -79.387042    M5V 2T6    ON
# 7                      35 Church St  43.648824 -79.373702    M5E 1T3    ON
# 8               37 King Street East  43.649298 -79.376431    M5C 1E9    ON
# 9                    476 Dundas St.  43.653185 -79.396677        NaN    ON
# 10                   287 King St. W  43.646463 -79.389644    M5V 1J5    ON
# 11                 30 Mercer Street  43.645634 -79.391125    M5V 1H3    ON
# 12            100 Cumberland Street  43.670342 -79.391041    M5R 1A6    ON
# 13                 353 Spadina Ave.  43.655337 -79.398897    M5T 2G3    ON
# 14                  8 St Andrew St.  43.654307 -79.399277    M5T 1K6    ON
# 15                    14 Queen St W  43.652614 -79.380231    M5H 3X4    ON
# 16                116 Yorkville Ave  43.670809 -79.393272        NaN    ON
# 17                563 Bloor St West  43.665180 -79.410966    M5S 1Y6    ON
# 18               988 Baldwin Street  43.655874 -79.393826        NaN    ON
# 19                  195 Dundas St W  43.654925 -79.387089    M5G 1C7    ON
# 20                  405 Spadina Ave  43.656794 -79.399251    M5T 2G6    ON
# 21  261 Spadina Avenue. Upper level  43.652488 -79.397501    M5T 2E3    ON
# 22                1132 Dundas St. W  43.649435 -79.420390    M6J 1X2    ON
# 23               2A Kensington Ave.  43.652803 -79.399958    M5T 2J7    ON
# 24              293 Palmerston Ave.  43.655765 -79.409929    M6J 2J3    ON
# 25                   389 Church St.  43.661500 -79.379319        M5B    ON
# 26                    Rogers Centre  43.641635 -79.389365        NaN    ON
# 27                   70 Fraser Ave.  43.637775 -79.424297    M6K 3C5    ON
# 28              143 Dundas St. West  43.655381 -79.385270        NaN    ON
# 29              249 Victoria Street  43.655641 -79.379199    M5B 1T8    ON

# %%
# delete rows with none values
df_Restaurant = clean_Restaurant_dataframe2.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
df_Restaurant
# Out:
#                                               name               categories  \
# 0                           Rol San Restaurant 龍笙棧       Dim Sum Restaurant
# 1                  Hemispheres Restaurant & Bistro      American Restaurant
# 2                           Azure Restaurant & Bar               Restaurant
# 3                   Goldstone Noodle Restaurant 金石             Noodle House
# 5                          Swatow Restaurant 汕頭小食家       Chinese Restaurant
# 6                                   360 Restaurant                 Wine Bar
# 7                   The Hot House Restaurant & Bar      American Restaurant
# 8                            Victoria's Restaurant               Restaurant
# 10                    Aroma Fine Indian Restaurant        Indian Restaurant
# 11                         Victor Restaurant & Bar                      Bar
# 12  Sassafraz | Cafe | Restaurant | Private Events              Event Space
# 13                        New Sky Restaurant 小沙田食家       Chinese Restaurant
# 14                        Ka Chi Korean Restaurant        Korean Restaurant
# 15             Richtree Natural Market Restaurants               Restaurant
# 17                  Insomnia Restaurant and Lounge               Restaurant
# 19                   Hong Shing Chinese Restaurant       Chinese Restaurant
# 20         Tasty's Caribbean Restaurant & Catering     Caribbean Restaurant
# 21                   Green Tea Restaurant Downtown       Chinese Restaurant
# 22                         The Lakeview Restaurant                    Diner
# 23               Kensington Cornerstone Restaurant           Breakfast Spot
# 24                     Woodlot Restaurant & Bakery  New American Restaurant
# 25                               Studio Restaurant           Breakfast Spot
# 27                               SCHOOL Restaurant           Breakfast Spot
# 29                          The Senator Restaurant                    Diner
#
#                             address        lat        lng postalCode state
# 0                  323 Spadina Ave.  43.654318 -79.398650    M5T 2E9    ON
# 1               110 Chestnut Street  43.654884 -79.385931    M5G 1R3    ON
# 2                     225 Frnt St W  43.644749 -79.385113    M5V 2X3    ON
# 3                   266 Spadina Ave  43.652278 -79.398039    M5T 2E4    ON
# 5                  309 Spadina Ave.  43.653866 -79.398334    M5T 2E6    ON
# 6                    301 Front St W  43.642537 -79.387042    M5V 2T6    ON
# 7                      35 Church St  43.648824 -79.373702    M5E 1T3    ON
# 8               37 King Street East  43.649298 -79.376431    M5C 1E9    ON
# 10                   287 King St. W  43.646463 -79.389644    M5V 1J5    ON
# 11                 30 Mercer Street  43.645634 -79.391125    M5V 1H3    ON
# 12            100 Cumberland Street  43.670342 -79.391041    M5R 1A6    ON
# 13                 353 Spadina Ave.  43.655337 -79.398897    M5T 2G3    ON
# 14                  8 St Andrew St.  43.654307 -79.399277    M5T 1K6    ON
# 15                    14 Queen St W  43.652614 -79.380231    M5H 3X4    ON
# 17                563 Bloor St West  43.665180 -79.410966    M5S 1Y6    ON
# 19                  195 Dundas St W  43.654925 -79.387089    M5G 1C7    ON
# 20                  405 Spadina Ave  43.656794 -79.399251    M5T 2G6    ON
# 21  261 Spadina Avenue. Upper level  43.652488 -79.397501    M5T 2E3    ON
# 22                1132 Dundas St. W  43.649435 -79.420390    M6J 1X2    ON
# 23               2A Kensington Ave.  43.652803 -79.399958    M5T 2J7    ON
# 24              293 Palmerston Ave.  43.655765 -79.409929    M6J 2J3    ON
# 25                   389 Church St.  43.661500 -79.379319        M5B    ON
# 27                   70 Fraser Ave.  43.637775 -79.424297    M6K 3C5    ON
# 29              249 Victoria Street  43.655641 -79.379199    M5B 1T8    ON

# %% [markdown]
# ## **Search for Cafeteria**

# %%
# search for Cafeteria
search_query = 'Cafeteria'
radius = 10000

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=4FQQJE2LMGVLERRRE2BOFR1LQQR5ZEHFLTD1WRAFKOFT4TI0&client_secret=RCSNR5TH31NQRG2QYCHK101HRMTUZHBB2TSJ1CJU5UOGRXRQ&ll=43.653963,-79.387207&v=20180604&query=Cafeteria&radius=10000&limit=30'

# %%
# Send the GET Request and examine the results
cresults = requests.get(url).json()
#cresults

# %%
# assign relevant part of JSON to venues
venues = cresults['response']['venues']

# tranform venues into a dataframe
Cafeteria_dataframe = json_normalize(venues)
Cafeteria_dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d16e941735', 'name': 'F...    False
# 1  [{'id': '4bf58dd8d48988d142941735', 'name': 'A...    False
# 2  [{'id': '4bf58dd8d48988d1a1941735', 'name': 'C...    False
# 3  [{'id': '4bf58dd8d48988d1c1941735', 'name': 'M...    False
# 4  [{'id': '4bf58dd8d48988d128941735', 'name': 'C...    False
#
#                          id                           location.address  \
# 0  4f9165bde4b04fef0087e4e2  The Hospital for Sick Children (SickKids)
# 1  528e99a211d262edc3708a6f                            388 Spadina Ave
# 2  4ec2b68a8231a83de8c45191                             100 McCaul St.
# 3  56b2c90a498e9f0e73d6bed6                             974 College St
# 4  53bd6dfe498e6c1d3bc9333e                                        NaN
#
#   location.cc location.city location.country location.crossStreet  \
# 0          CA       Toronto           Canada                  NaN
# 1          CA       Toronto           Canada         at Nassau St
# 2          CA       Toronto           Canada         Second Floor
# 3          CA       Toronto           Canada                  NaN
# 4          CA       Toronto           Canada                  NaN
#
#    location.distance                          location.formattedAddress  \
# 0                372  [The Hospital for Sick Children (SickKids), To...
# 1                977  [388 Spadina Ave (at Nassau St), Toronto ON M5...
# 2                389  [100 McCaul St. (Second Floor), Toronto ON, Ca...
# 3               3260       [974 College St, Toronto ON M6H 1A5, Canada]
# 4                260                               [Toronto ON, Canada]
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 43.65720930549997...     43.657209
# 1  [{'label': 'display', 'lat': 43.65545427446646...     43.655454
# 2  [{'label': 'display', 'lat': 43.65278016892648...     43.652780
# 3  [{'label': 'display', 'lat': 43.65341883567197...     43.653419
# 4  [{'label': 'display', 'lat': 43.655657, 'lng':...     43.655657
#
#    location.lng location.postalCode location.state  \
# 0    -79.386063                 NaN             ON
# 1    -79.399163             M5T 2G5             ON
# 2    -79.391762                 NaN             ON
# 3    -79.427678             M6H 1A5             ON
# 4    -79.389443                 NaN             ON
#
#                             name    referralId
# 0                      Cafeteria  v-1568567570
# 1              Stay Cafeteria 慢走  v-1568567570
# 2                 OCAD Cafeteria  v-1568567570
# 3                      Cafeteria  v-1568567570
# 4  Industrial Alliance Cafeteria  v-1568567570

# %% [markdown]
# ## **Clean Cafeteria Dataframe**

# %%
# keep only columns that include venue name, and anything that is associated with location
Cafeteria_clean_columns = ['name', 'categories'] + [col for col in Cafeteria_dataframe.columns if col.startswith('location.')]+ ['id']
clean_Cafeteria_dataframe = Cafeteria_dataframe.loc[:,Cafeteria_clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list4 = row['categories']
    except:
        categories_list4 = row['venue.categories']
        
    if len(categories_list4) == 0:
        return None
    else:
        return categories_list4[0]['name']

# filter the category for each row
clean_Cafeteria_dataframe['categories'] = clean_Cafeteria_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_Cafeteria_dataframe.columns = [column.split('.')[-1] for column in clean_Cafeteria_dataframe.columns]

clean_Cafeteria_dataframe.head()
# Out:
#                             name            categories  \
# 0                      Cafeteria  Fast Food Restaurant
# 1              Stay Cafeteria 慢走      Asian Restaurant
# 2                 OCAD Cafeteria     College Cafeteria
# 3                      Cafeteria    Mexican Restaurant
# 4  Industrial Alliance Cafeteria             Cafeteria
#
#                                      address  cc     city country  \
# 0  The Hospital for Sick Children (SickKids)  CA  Toronto  Canada
# 1                            388 Spadina Ave  CA  Toronto  Canada
# 2                             100 McCaul St.  CA  Toronto  Canada
# 3                             974 College St  CA  Toronto  Canada
# 4                                        NaN  CA  Toronto  Canada
#
#     crossStreet  distance                                   formattedAddress  \
# 0           NaN       372  [The Hospital for Sick Children (SickKids), To...
# 1  at Nassau St       977  [388 Spadina Ave (at Nassau St), Toronto ON M5...
# 2  Second Floor       389  [100 McCaul St. (Second Floor), Toronto ON, Ca...
# 3           NaN      3260       [974 College St, Toronto ON M6H 1A5, Canada]
# 4           NaN       260                               [Toronto ON, Canada]
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 43.65720930549997...  43.657209 -79.386063
# 1  [{'label': 'display', 'lat': 43.65545427446646...  43.655454 -79.399163
# 2  [{'label': 'display', 'lat': 43.65278016892648...  43.652780 -79.391762
# 3  [{'label': 'display', 'lat': 43.65341883567197...  43.653419 -79.427678
# 4  [{'label': 'display', 'lat': 43.655657, 'lng':...  43.655657 -79.389443
#
#   postalCode state                        id
# 0        NaN    ON  4f9165bde4b04fef0087e4e2
# 1    M5T 2G5    ON  528e99a211d262edc3708a6f
# 2        NaN    ON  4ec2b68a8231a83de8c45191
# 3    M6H 1A5    ON  56b2c90a498e9f0e73d6bed6
# 4        NaN    ON  53bd6dfe498e6c1d3bc9333e

# %%
# delete unnecessary columns
clean_Cafeteria_dataframe2= clean_Cafeteria_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs', 'id'], axis=1)
clean_Cafeteria_dataframe2
# Out:
#                                      name            categories  \
# 0                               Cafeteria  Fast Food Restaurant
# 1                       Stay Cafeteria 慢走      Asian Restaurant
# 2                          OCAD Cafeteria     College Cafeteria
# 3                               Cafeteria    Mexican Restaurant
# 4           Industrial Alliance Cafeteria             Cafeteria
# 5                         Dears Cafeteria          Dessert Shop
# 6                 Chestnut Tree Cafeteria             Cafeteria
# 7                         Sears Cafeteria            Food Court
# 8           De La Salle College Cafeteria     College Cafeteria
# 9                       Med Sci Cafeteria     College Cafeteria
# 10                  Ryerson Hub Cafeteria     College Cafeteria
# 11                     SickKids Cafeteria            Food Court
# 12              Macdonald Block Cafeteria             Cafeteria
# 13                      Robarts Cafeteria     College Cafeteria
# 14  George Brown College St. James Campus     Community College
# 15                          OMP Cafeteria             Cafeteria
# 16                       Rogers Cafeteria            Food Court
# 17                      Choices Cafeteria            Food Court
# 18    Cafeteria, Lawrence Park Collegiate           High School
# 19                       Kasala Cafeteria    African Restaurant
# 20    Cafeteria, Lawrence Park Collegiate           Event Space
# 21                             Marketeria            Restaurant
# 22                                The Hub     College Cafeteria
# 23               Estonian House Cafeteria                  Café
# 24                           CC Cafeteria     College Cafeteria
# 25                             Radio Cafe            Food Court
# 26                          Innis College        Student Center
# 27                               One Hour    Chinese Restaurant
# 28     Lawrence Park Collegiate Cafeteria           High School
# 29                      Glendon Cafeteria     College Cafeteria
#
#                                       address        lat        lng  \
# 0   The Hospital for Sick Children (SickKids)  43.657209 -79.386063
# 1                             388 Spadina Ave  43.655454 -79.399163
# 2                              100 McCaul St.  43.652780 -79.391762
# 3                              974 College St  43.653419 -79.427678
# 4                                         NaN  43.655657 -79.389443
# 5                                         NaN  43.654179 -79.392555
# 6                          89 Chestnut Street  43.648231 -79.384045
# 7                                       Yonge  43.656038 -79.380672
# 8                          131 Farnham Avenue  43.683003 -79.397815
# 9                                         NaN  43.660260 -79.392977
# 10                           350 Victoria St.  43.658475 -79.377653
# 11                      555 University Avenue  43.657584 -79.375652
# 12                                        NaN  43.663212 -79.388062
# 13                         130 St. George St.  43.664864 -79.399766
# 14                             51 Dockside Dr  43.644163 -79.366375
# 15                           1 Mount Pleasant  43.669801 -79.379790
# 16                                        NaN  43.669904 -79.379748
# 17                         200 Bloor Street E  43.671411 -79.381849
# 18                                        NaN  43.721732 -79.409600
# 19                                      Bloor  43.660759 -79.424018
# 20                                        NaN  43.723286 -79.412222
# 21                                30 Bond St.  43.653585 -79.378843
# 22                           350 Victoria St.  43.658585 -79.380622
# 23                       958 Broadview avenue  43.681763 -79.358246
# 24                             951 Carlaw Ave  43.684631 -79.348862
# 25                          333 Bloor st east  43.671696 -79.380617
# 26                               2 Sussex Ave  43.665556 -79.399298
# 27                           435 Spadina Ave.  43.657399 -79.399649
# 28                                        NaN  43.722757 -79.413734
# 29                           2275 Bayview Ave  43.727383 -79.378080
#
#    postalCode state
# 0         NaN    ON
# 1     M5T 2G5    ON
# 2         NaN    ON
# 3     M6H 1A5    ON
# 4         NaN    ON
# 5         NaN   NaN
# 6         NaN    ON
# 7         NaN    ON
# 8     M4V 1H7    ON
# 9         NaN    ON
# 10        NaN    ON
# 11        NaN    ON
# 12        NaN   NaN
# 13        NaN    ON
# 14    M5A 0B6    ON
# 15        NaN    ON
# 16        NaN    ON
# 17        NaN    ON
# 18        NaN   NaN
# 19        NaN   NaN
# 20        NaN   NaN
# 21    M5B 1W8    ON
# 22    M5B 2K3    ON
# 23        NaN    ON
# 24        NaN    ON
# 25        NaN    ON
# 26    M5S 1J5    ON
# 27    M5T 2T6    ON
# 28        NaN    ON
# 29        NaN    ON

# %%
# delete rows with none values
df_Cafeteria = clean_Cafeteria_dataframe2.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
df_Cafeteria
# Out:
#                                      name          categories  \
# 1                       Stay Cafeteria 慢走    Asian Restaurant
# 3                               Cafeteria  Mexican Restaurant
# 8           De La Salle College Cafeteria   College Cafeteria
# 14  George Brown College St. James Campus   Community College
# 21                             Marketeria          Restaurant
# 22                                The Hub   College Cafeteria
# 26                          Innis College      Student Center
# 27                               One Hour  Chinese Restaurant
#
#                address        lat        lng postalCode state
# 1      388 Spadina Ave  43.655454 -79.399163    M5T 2G5    ON
# 3       974 College St  43.653419 -79.427678    M6H 1A5    ON
# 8   131 Farnham Avenue  43.683003 -79.397815    M4V 1H7    ON
# 14      51 Dockside Dr  43.644163 -79.366375    M5A 0B6    ON
# 21         30 Bond St.  43.653585 -79.378843    M5B 1W8    ON
# 22    350 Victoria St.  43.658585 -79.380622    M5B 2K3    ON
# 26        2 Sussex Ave  43.665556 -79.399298    M5S 1J5    ON
# 27    435 Spadina Ave.  43.657399 -79.399649    M5T 2T6    ON

# %% [markdown]
# ## **Search for Shopping Stores**

# %%
# search for Shopping
search_query = 'Shopping'
radius = 1000

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=4FQQJE2LMGVLERRRE2BOFR1LQQR5ZEHFLTD1WRAFKOFT4TI0&client_secret=RCSNR5TH31NQRG2QYCHK101HRMTUZHBB2TSJ1CJU5UOGRXRQ&ll=43.653963,-79.387207&v=20180604&query=Shopping&radius=1000&limit=30'

# %%
# Send the GET Request and examine the results
sresults = requests.get(url).json()
#sresults

# %%
# assign relevant part of JSON to venues
venues = sresults['response']['venues']

# tranform venues into a dataframe
Shopping_dataframe = json_normalize(venues)
Shopping_dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1fd941735', 'name': 'S...    False
# 1  [{'id': '4bf58dd8d48988d1fd941735', 'name': 'S...    False
# 2  [{'id': '4bf58dd8d48988d1fd941735', 'name': 'S...    False
# 3  [{'id': '4bf58dd8d48988d1f6941735', 'name': 'D...    False
# 4  [{'id': '4bf58dd8d48988d124941735', 'name': 'O...    False
#
#                          id    location.address location.cc location.city  \
# 0  4ad4c062f964a520fcf720e3     280 Spadina Ave          CA       Toronto
# 1  4ad77a12f964a520260b21e3        220 Yonge St          CA       Toronto
# 2  4b9e86dff964a520e6eb36e3  66 Wellington St W          CA       Toronto
# 3  5840cafe06f1a34af80cc609    176 Yonge Street          CA       Toronto
# 4  4b83d653f964a520d91231e3   461 King St. West          CA       Toronto
#
#   location.country location.crossStreet  location.distance  \
# 0           Canada       at Dundas St W                897
# 1           Canada  btwn Queen & Dundas                535
# 2           Canada    btw York & Bay St                908
# 3           Canada    Queen Street West                688
# 4           Canada                  NaN                974
#
#                            location.formattedAddress  \
# 0  [280 Spadina Ave (at Dundas St W), Toronto ON ...
# 1  [220 Yonge St (btwn Queen & Dundas), Toronto O...
# 2  [66 Wellington St W (btw York & Bay St), Toron...
# 3  [176 Yonge Street (Queen Street West), Toronto...
# 4    [461 King St. West, Toronto ON M5V 1K4, Canada]
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 43.65277367198862...     43.652774
# 1                                                NaN     43.654265
# 2  [{'label': 'display', 'lat': 43.64718424611984...     43.647184
# 3  [{'label': 'display', 'lat': 43.65181, 'lng': ...     43.651810
# 4  [{'label': 'display', 'lat': 43.64795765580337...     43.647958
#
#    location.lng          location.neighborhood location.postalCode  \
# 0    -79.398222                            NaN             M5T 3A5
# 1    -79.380567  Downtown Toronto, Toronto, ON             M5B 2H1
# 2    -79.380932                            NaN             M5K 1A1
# 3    -79.379192                            NaN             M5C 2L7
# 4    -79.396006                            NaN             M5V 1K4
#
#   location.state                                        name    referralId
# 0             ON                Dragon City Shopping Mall 龍城  v-1568567573
# 1             ON                     CF Toronto Eaton Centre  v-1568567573
# 2             ON                TD Centre Shopping Concourse  v-1568567573
# 3             ON  Saks Fifth Avenue Club - Personal Shopping  v-1568567573
# 4             ON             Yellow Pages - RedFlagDeals.com  v-1568567573

# %% [markdown]
# ## **Clean Shopping Dataframe**

# %%
# keep only columns that include venue name, and anything that is associated with location
Shopping_clean_columns = ['name', 'categories'] + [col for col in Shopping_dataframe.columns if col.startswith('location.')]+ ['id']
clean_Shopping_dataframe = Shopping_dataframe.loc[:,Shopping_clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list5 = row['categories']
    except:
        categories_list5 = row['venue.categories']
        
    if len(categories_list5) == 0:
        return None
    else:
        return categories_list5[0]['name']

# filter the category for each row
clean_Shopping_dataframe['categories'] = clean_Shopping_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_Shopping_dataframe.columns = [column.split('.')[-1] for column in clean_Shopping_dataframe.columns]

clean_Shopping_dataframe.head()
# Out:
#                                          name        categories  \
# 0                Dragon City Shopping Mall 龍城     Shopping Mall
# 1                     CF Toronto Eaton Centre     Shopping Mall
# 2                TD Centre Shopping Concourse     Shopping Mall
# 3  Saks Fifth Avenue Club - Personal Shopping  Department Store
# 4             Yellow Pages - RedFlagDeals.com            Office
#
#               address  cc     city country          crossStreet  distance  \
# 0     280 Spadina Ave  CA  Toronto  Canada       at Dundas St W       897
# 1        220 Yonge St  CA  Toronto  Canada  btwn Queen & Dundas       535
# 2  66 Wellington St W  CA  Toronto  Canada    btw York & Bay St       908
# 3    176 Yonge Street  CA  Toronto  Canada    Queen Street West       688
# 4   461 King St. West  CA  Toronto  Canada                  NaN       974
#
#                                     formattedAddress  \
# 0  [280 Spadina Ave (at Dundas St W), Toronto ON ...
# 1  [220 Yonge St (btwn Queen & Dundas), Toronto O...
# 2  [66 Wellington St W (btw York & Bay St), Toron...
# 3  [176 Yonge Street (Queen Street West), Toronto...
# 4    [461 King St. West, Toronto ON M5V 1K4, Canada]
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 43.65277367198862...  43.652774 -79.398222
# 1                                                NaN  43.654265 -79.380567
# 2  [{'label': 'display', 'lat': 43.64718424611984...  43.647184 -79.380932
# 3  [{'label': 'display', 'lat': 43.65181, 'lng': ...  43.651810 -79.379192
# 4  [{'label': 'display', 'lat': 43.64795765580337...  43.647958 -79.396006
#
#                     neighborhood postalCode state                        id
# 0                            NaN    M5T 3A5    ON  4ad4c062f964a520fcf720e3
# 1  Downtown Toronto, Toronto, ON    M5B 2H1    ON  4ad77a12f964a520260b21e3
# 2                            NaN    M5K 1A1    ON  4b9e86dff964a520e6eb36e3
# 3                            NaN    M5C 2L7    ON  5840cafe06f1a34af80cc609
# 4                            NaN    M5V 1K4    ON  4b83d653f964a520d91231e3

# %%
# delete unnecessary columns
clean_Shopping_dataframe2= clean_Shopping_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs', 'neighborhood', 'id'], axis=1)
clean_Shopping_dataframe2
# Out:
#                                          name        categories  \
# 0                Dragon City Shopping Mall 龍城     Shopping Mall
# 1                     CF Toronto Eaton Centre     Shopping Mall
# 2                TD Centre Shopping Concourse     Shopping Mall
# 3  Saks Fifth Avenue Club - Personal Shopping  Department Store
# 4             Yellow Pages - RedFlagDeals.com            Office
#
#               address        lat        lng postalCode state
# 0     280 Spadina Ave  43.652774 -79.398222    M5T 3A5    ON
# 1        220 Yonge St  43.654265 -79.380567    M5B 2H1    ON
# 2  66 Wellington St W  43.647184 -79.380932    M5K 1A1    ON
# 3    176 Yonge Street  43.651810 -79.379192    M5C 2L7    ON
# 4   461 King St. West  43.647958 -79.396006    M5V 1K4    ON

# %%
# delete rows which its category is not Shopping Mall
df_Shopping = clean_Shopping_dataframe2[clean_Shopping_dataframe2.categories == 'Shopping Mall']
df_Shopping
# Out:
#                            name     categories             address        lat  \
# 0  Dragon City Shopping Mall 龍城  Shopping Mall     280 Spadina Ave  43.652774
# 1       CF Toronto Eaton Centre  Shopping Mall        220 Yonge St  43.654265
# 2  TD Centre Shopping Concourse  Shopping Mall  66 Wellington St W  43.647184
#
#          lng postalCode state
# 0 -79.398222    M5T 3A5    ON
# 1 -79.380567    M5B 2H1    ON
# 2 -79.380932    M5K 1A1    ON

# %% [markdown]
# ## **Generate map to visualize hotels, shopping stores and Cafeteria and how they cluster together**

# %%
# create dataframe of hotels, shopping stores and Cafeteria
hotel_neighbourhood_df = pd.concat([df_hotel, df_Cafeteria, df_Shopping], ignore_index=True)
hotel_neighbourhood_df
# Out:
#                                      name          categories  \
# 0           Sheraton Centre Toronto Hotel               Hotel
# 1                          Grand Ballroom         Event Space
# 2                       Stay Cafeteria 慢走    Asian Restaurant
# 3                               Cafeteria  Mexican Restaurant
# 4           De La Salle College Cafeteria   College Cafeteria
# 5   George Brown College St. James Campus   Community College
# 6                              Marketeria          Restaurant
# 7                                 The Hub   College Cafeteria
# 8                           Innis College      Student Center
# 9                                One Hour  Chinese Restaurant
# 10           Dragon City Shopping Mall 龍城       Shopping Mall
# 11                CF Toronto Eaton Centre       Shopping Mall
# 12           TD Centre Shopping Concourse       Shopping Mall
#
#                   address        lat        lng postalCode state
# 0   123 Queen Street West  43.651144 -79.384329    M5H 2M9    ON
# 1         123 Queen St. W  43.651217 -79.383771    M5H 2M9    ON
# 2         388 Spadina Ave  43.655454 -79.399163    M5T 2G5    ON
# 3          974 College St  43.653419 -79.427678    M6H 1A5    ON
# 4      131 Farnham Avenue  43.683003 -79.397815    M4V 1H7    ON
# 5          51 Dockside Dr  43.644163 -79.366375    M5A 0B6    ON
# 6             30 Bond St.  43.653585 -79.378843    M5B 1W8    ON
# 7        350 Victoria St.  43.658585 -79.380622    M5B 2K3    ON
# 8            2 Sussex Ave  43.665556 -79.399298    M5S 1J5    ON
# 9        435 Spadina Ave.  43.657399 -79.399649    M5T 2T6    ON
# 10        280 Spadina Ave  43.652774 -79.398222    M5T 3A5    ON
# 11           220 Yonge St  43.654265 -79.380567    M5B 2H1    ON
# 12     66 Wellington St W  43.647184 -79.380932    M5K 1A1    ON

# %%
# Generate map to visualize hotel neighbourhood including shopping stores and Cafeteria 
hotel_map = folium.Map(location=[latitude, longitude], zoom_start=14)

for lat, lng, name, categories, address in zip(hotel_neighbourhood_df['lat'], hotel_neighbourhood_df['lng'], 
                                           hotel_neighbourhood_df['name'], hotel_neighbourhood_df['categories'],\
                                               hotel_neighbourhood_df['address']):
    label = '{}, {}'.format(name, address)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='blue',
        fill_opacity=0.7,
        parse_html=False).add_to(hotel_map)  
    
hotel_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## **Generate map to visualize Park, Restaurant and Cafeteria and how they cluster together**

# %%
# create dataframe of Park, Restaurant and Cafeteria
park_neighbourhood_df = pd.concat([df_park, df_Restaurant, df_Cafeteria,], ignore_index=True)
park_neighbourhood_df
# Out:
# C:\Users\Heman\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
#                             address               categories        lat  \
# 0                 255 Bremner Blvd.                     Park  43.641745
# 1                  323 Spadina Ave.       Dim Sum Restaurant  43.654318
# 2               110 Chestnut Street      American Restaurant  43.654884
# 3                     225 Frnt St W               Restaurant  43.644749
# 4                   266 Spadina Ave             Noodle House  43.652278
# 5                  309 Spadina Ave.       Chinese Restaurant  43.653866
# 6                    301 Front St W                 Wine Bar  43.642537
# 7                      35 Church St      American Restaurant  43.648824
# 8               37 King Street East               Restaurant  43.649298
# 9                    287 King St. W        Indian Restaurant  43.646463
# 10                 30 Mercer Street                      Bar  43.645634
# 11            100 Cumberland Street              Event Space  43.670342
# 12                 353 Spadina Ave.       Chinese Restaurant  43.655337
# 13                  8 St Andrew St.        Korean Restaurant  43.654307
# 14                    14 Queen St W               Restaurant  43.652614
# 15                563 Bloor St West               Restaurant  43.665180
# 16                  195 Dundas St W       Chinese Restaurant  43.654925
# 17                  405 Spadina Ave     Caribbean Restaurant  43.656794
# 18  261 Spadina Avenue. Upper level       Chinese Restaurant  43.652488
# 19                1132 Dundas St. W                    Diner  43.649435
# 20               2A Kensington Ave.           Breakfast Spot  43.652803
# 21              293 Palmerston Ave.  New American Restaurant  43.655765
# 22                   389 Church St.           Breakfast Spot  43.661500
# 23                   70 Fraser Ave.           Breakfast Spot  43.637775
# 24              249 Victoria Street                    Diner  43.655641
# 25                  388 Spadina Ave         Asian Restaurant  43.655454
# 26                   974 College St       Mexican Restaurant  43.653419
# 27               131 Farnham Avenue        College Cafeteria  43.683003
# 28                   51 Dockside Dr        Community College  43.644163
# 29                      30 Bond St.               Restaurant  43.653585
# 30                 350 Victoria St.        College Cafeteria  43.658585
# 31                     2 Sussex Ave           Student Center  43.665556
# 32                 435 Spadina Ave.       Chinese Restaurant  43.657399
#
#           lng                                            name  \
# 0  -79.384279                                 Roundhouse Park
# 1  -79.398650                          Rol San Restaurant 龍笙棧
# 2  -79.385931                 Hemispheres Restaurant & Bistro
# 3  -79.385113                          Azure Restaurant & Bar
# 4  -79.398039                  Goldstone Noodle Restaurant 金石
# 5  -79.398334                         Swatow Restaurant 汕頭小食家
# 6  -79.387042                                  360 Restaurant
# 7  -79.373702                  The Hot House Restaurant & Bar
# 8  -79.376431                           Victoria's Restaurant
# 9  -79.389644                    Aroma Fine Indian Restaurant
# 10 -79.391125                         Victor Restaurant & Bar
# 11 -79.391041  Sassafraz | Cafe | Restaurant | Private Events
# 12 -79.398897                        New Sky Restaurant 小沙田食家
# 13 -79.399277                        Ka Chi Korean Restaurant
# 14 -79.380231             Richtree Natural Market Restaurants
# 15 -79.410966                  Insomnia Restaurant and Lounge
# 16 -79.387089                   Hong Shing Chinese Restaurant
# 17 -79.399251         Tasty's Caribbean Restaurant & Catering
# 18 -79.397501                   Green Tea Restaurant Downtown
# 19 -79.420390                         The Lakeview Restaurant
# 20 -79.399958               Kensington Cornerstone Restaurant
# 21 -79.409929                     Woodlot Restaurant & Bakery
# 22 -79.379319                               Studio Restaurant
# 23 -79.424297                               SCHOOL Restaurant
# 24 -79.379199                          The Senator Restaurant
# 25 -79.399163                               Stay Cafeteria 慢走
# 26 -79.427678                                       Cafeteria
# 27 -79.397815                   De La Salle College Cafeteria
# 28 -79.366375           George Brown College St. James Campus
# 29 -79.378843                                      Marketeria
# 30 -79.380622                                         The Hub
# 31 -79.399298                                   Innis College
# 32 -79.399649                                        One Hour
#
#               neighborhood postalCode state
# 0   Entertainment District    M5V 3M9    ON
# 1                      NaN    M5T 2E9    ON
# 2                      NaN    M5G 1R3    ON
# 3                      NaN    M5V 2X3    ON
# 4                      NaN    M5T 2E4    ON
# 5                      NaN    M5T 2E6    ON
# 6                      NaN    M5V 2T6    ON
# 7                      NaN    M5E 1T3    ON
# 8                      NaN    M5C 1E9    ON
# 9                      NaN    M5V 1J5    ON
# 10                     NaN    M5V 1H3    ON
# 11                     NaN    M5R 1A6    ON
# 12                     NaN    M5T 2G3    ON
# 13                     NaN    M5T 1K6    ON
# 14                     NaN    M5H 3X4    ON
# 15                     NaN    M5S 1Y6    ON
# 16                     NaN    M5G 1C7    ON
# 17                     NaN    M5T 2G6    ON
# 18                     NaN    M5T 2E3    ON
# 19                     NaN    M6J 1X2    ON
# 20                     NaN    M5T 2J7    ON
# 21                     NaN    M6J 2J3    ON
# 22                     NaN        M5B    ON
# 23                     NaN    M6K 3C5    ON
# 24                     NaN    M5B 1T8    ON
# 25                     NaN    M5T 2G5    ON
# 26                     NaN    M6H 1A5    ON
# 27                     NaN    M4V 1H7    ON
# 28                     NaN    M5A 0B6    ON
# 29                     NaN    M5B 1W8    ON
# 30                     NaN    M5B 2K3    ON
# 31                     NaN    M5S 1J5    ON
# 32                     NaN    M5T 2T6    ON

# %%
# Generate map to visualize park neighbourhood including Restaurant and Cafeteria 
park_map = folium.Map(location=[latitude, longitude], zoom_start=14)

for lat, lng, name, categories, address in zip(park_neighbourhood_df['lat'], park_neighbourhood_df['lng'], 
                                           park_neighbourhood_df['name'], park_neighbourhood_df['categories'],\
                                               park_neighbourhood_df['address']):
    label = '{}, {}'.format(name, address)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='blue',
        fill_opacity=0.7,
        parse_html=False).add_to(park_map)  
    
park_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
